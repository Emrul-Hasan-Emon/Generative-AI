# %% [markdown]
# <a href="https://colab.research.google.com/github/Emrul-Hasan-Emon/Generative-AI/blob/main/3.%20Text%20Classification/text_classification_using_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataset Link**: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix

from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 255)

# %% [markdown]
# # Data Collection
#
# To download datasets from Kaggle, you need to authenticate using your Kaggle API token. Follow these steps:
#
# 1.  Go to your Kaggle account page: [https://www.kaggle.com/me/account](https://www.kaggle.com/me/account)
# 2.  Scroll down to the 'API' section and click 'Create New API Token'. This will download a `kaggle.json` file to your computer.
# 3.  In Google Colab, click on the 'Files' icon (folder icon) on the left sidebar.
# 4.  Upload the `kaggle.json` file you just downloaded to the `/root/.kaggle/` directory. If the `.kaggle` directory doesn't exist, you'll create it in the next step.
#
# Alternatively, you can store your `kaggle.json` content as a Colab secret named `KAGGLE_API_TOKEN` and use the following code to create the file programmatically.

# %%
# Install the Kaggle library
# !pip install kaggle

# %%
# Create the .kaggle directory and move the kaggle.json file
import os

# Ensure the .kaggle directory exists
if not os.path.exists('/root/.kaggle'):
    os.makedirs('/root/.kaggle')

# Option 1: If you uploaded kaggle.json manually to /root/.kaggle/ (recommended for simplicity)
# No code needed if you manually uploaded.

# Option 2: If you want to use Colab Secrets for kaggle.json content
# from google.colab import userdata
# with open('/root/.kaggle/kaggle.json', 'w') as f:
#     f.write(userdata.get('KAGGLE_API_TOKEN'))

# %% [markdown]
# Now, let's download the dataset.

# %%
# Download the dataset
# The dataset link is https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# The command format is: !kaggle datasets download -d <owner>/<dataset-name>
# !kaggle datasets download -d lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# License(s): other
# ...
# 100% 25.7M/25.7M [00:00<00:00, 95.5MB/s]

# %%
# Unzip the downloaded file
import zipfile
import os

# Define the path to the downloaded zip file
zip_file_path = 'imdb-dataset-of-50k-movie-reviews.zip'

# Define the directory to extract the contents
extraction_path = '.' # Extract to the current directory

# Create the extraction directory if it doesn't exist
if not os.path.exists(extraction_path):
    os.makedirs(extraction_path)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print(f"'{zip_file_path}' extracted to '{extraction_path}'.")
# Out:
# 'imdb-dataset-of-50k-movie-reviews.zip' extracted to '.'.

# %% [markdown]
# Now, let's load the `IMDB Dataset.csv` file into a pandas DataFrame and display its first 5 rows.

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('IMDB Dataset.csv')

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#                                                                                                                                                                                                                                                            review  \
# 0  One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of v...
# 1  A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. <br /><br />The actors are extremely well chosen-...
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Sentiment Distribution

# %%
# Visualize the distribution of sentiments
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='sentiment', palette='viridis')
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# Display the value counts for sentiments
print("\nSentiment Value Counts:")
display(df['sentiment'].value_counts())
# Out:
# /tmp/ipykernel_3068/259357966.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment', palette='viridis')
# Sentiment Value Counts:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (50000, 3)

# %% [markdown]
# We have reviews nearly 50K. But we will work with 10K for now.

# %%
df = df.iloc[:10000]
df.head()
# Out:
#                                                                                                                                                                                                                                                            review  \
# 0  One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of v...
# 1  A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. <br /><br />The actors are extremely well chosen-...
# ...

# %%
df['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    5028
# negative    4972
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Remove HTML Tags

# %%
import re
def remove_tags(raw_text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', raw_text)
    return cleaned_text

# %%
df['review'] = df['review'].apply(remove_tags)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                            review  \
# 0  One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.The first thing that struck me about Oz was its brutality and unflinching scenes of violence, whi...
# 1  A wonderful little production. The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. The actors are extremely well chosen- Michael Sheen not only ...
# ...

# %% [markdown]
# ## Lower Case

# %%
df['review'] = df['review'].apply(lambda x:x.lower())

# %%
df['review'][0]
# Out:
# "one of the other reviewers has mentioned that after watching just 1 oz episode you'll be hooked. they are right, as this is exactly what happened with me.the first thing that struck me about oz was its brutality and unflinching scenes of violence, which set in right from the word go. trust me, this is not a show for the faint hearted or timid. this show pulls no punches with regards to drugs, sex or violence. its is hardcore, in the classic use of the word.it is called oz as that is the nickname given to the oswald maximum security state penitentary. it focuses mainly on emerald city, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. em city is home to many..aryans, muslims, gangstas, latinos, christians, italians, irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.i would say the main appeal of the show is due to the fact that it goes where other shows 
# ...

# %% [markdown]
# ### Stop Words Removal

# %%
sw_list = stopwords.words('english')
df['review'] = df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))

# %%
df['review'][0]
# Out:
# "one reviewers mentioned watching 1 oz episode hooked. right, exactly happened me.the first thing struck oz brutality unflinching scenes violence, set right word go. trust me, show faint hearted timid. show pulls punches regards drugs, sex violence. hardcore, classic use word.it called oz nickname given oswald maximum security state penitentary. focuses mainly emerald city, experimental section prison cells glass fronts face inwards, privacy high agenda. em city home many..aryans, muslims, gangstas, latinos, christians, italians, irish more....so scuffles, death stares, dodgy dealings shady agreements never far away.i would say main appeal show due fact goes shows dare. forget pretty pictures painted mainstream audiences, forget charm, forget romance...oz mess around. first episode ever saw struck nasty surreal, say ready it, watched more, developed taste oz, got accustomed high levels graphic violence. violence, injustice (crooked guards who'll sold nickel, inmates who'll kill order
# ...
